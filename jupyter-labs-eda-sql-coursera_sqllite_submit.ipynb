# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# ...
#   Using cached SQLAlchemy-1.3.9-cp312-cp312-linux_x86_64.whl
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.48
#     Uninstalling SQLAlchemy-2.0.48:
#       Successfully uninstalled SQLAlchemy-2.0.48
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.9 which is incompatible.
# jupyterhub 5.2.1 requires SQLAlchemy>=1.4.1, but you have sqlalchemy 1.3.9 which is incompatible.
# ...

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# ...
#   Using cached sqlalchemy-2.0.48-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# ...
# Using cached sqlalchemy-2.0.48-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select distinct Launch_Site from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
#
# %sql select * from SPACEXTABLE where Launch_Site like 'CCA%' limit 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %%
# %sql select count(*) from SPACEXTABLE where Landing_Outcome LIKE "Success (drone%"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(14,)]

# %%
# %sql select count(*) from SPACEXTABLE where Orbit LIKE "G%"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(30,)]

# %%
# %sql select count(*) from SPACEXTABLE where Launch_Site = "CCAFS SLC-40"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(34,)]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select max(PAYLOAD_MASS__KG_) from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(15600,)]

# %%
# PossAns:
# %sql select booster_version, max(PAYLOAD_MASS__KG_) from SPACEXTABLE where Customer = 'NASA (CRS)'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B4 B1039.1', 3310)]

# %%
# PossAns:
# %sql select booster_version, PAYLOAD_MASS__KG_ from SPACEXTABLE where Customer = 'NASA (CRS)' and PAYLOAD_MASS__KG_ = 3310
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B4 B1039.1', 3310)]

# %%
# BTW: The max for "SpaceX":
# %sql select max(PAYLOAD_MASS__KG_) from SPACEXTABLE where Customer = 'SpaceX'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(15600,)]

# %%
# BTW: The max for "SpaceX":
# %sql select booster_version, max(PAYLOAD_MASS__KG_) from SPACEXTABLE where Customer = 'SpaceX'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600)]

# %%
# %sql select booster_version, PAYLOAD_MASS__KG_ from SPACEXTABLE where Customer = 'NASA (CRS)' and PAYLOAD_MASS__KG_ = 3310 order by booster_version
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B4 B1039.1', 3310)]

# %%
# %sql select booster_version, PAYLOAD_MASS__KG_ from SPACEXTABLE where Customer = 'SpaceX' and PAYLOAD_MASS__KG_ = 15600
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1058.3 ', 15600),
#  ('F9 B5 B1051.6', 15600),
#  ('F9 B5 B1060.3', 15600),
#  ('F9 B5 B1049.7 ', 15600)]

# %%
# %sql select booster_version, PAYLOAD_MASS__KG_ from SPACEXTABLE where Customer = 'SpaceX' and PAYLOAD_MASS__KG_ = 15600
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1058.3 ', 15600),
#  ('F9 B5 B1051.6', 15600),
#  ('F9 B5 B1060.3', 15600),
#  ('F9 B5 B1049.7 ', 15600)]

# %%
# BTW: The max for "SpaceX":
# %sql select booster_version from SPACEXTABLE where PAYLOAD_MASS__KG_ = 15600 order by booster_version
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1049.7 ',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1060.3',)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# PossAns:
# %sql select avg(PAYLOAD_MASS__KG_) from SPACEXTABLE where Booster_Version = "F9 v1.1"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2928.4,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# PossAns:
# %sql select min(Date) from SPACEXTABLE where Mission_Outcome = 'Success'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04',)]

# %%
# PossAns:
# %sql select min(Date) from SPACEXTABLE where Landing_Outcome like '%Success%' and Landing_Outcome like '%drone ship%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2016-04-08',)]

# %%
# PossAns:
# %sql select min(Date) from SPACEXTABLE where Landing_Outcome like '%Success%' and Landing_Outcome like '%ground%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# PossAns:
# %sql select Booster_Version from SPACEXTABLE where Landing_Outcome = "Success (drone ship)" and PAYLOAD_MASS__KG_ > 4000 and PAYLOAD_MASS__KG_ < 6000
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# PossAns:
# %sql select count(Mission_Outcome) from SPACEXTABLE where Mission_Outcome like 'Success%' or Mission_Outcome like 'Failure%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(101,)]

# %%
# PossAns:
# %sql select count(Mission_Outcome) from SPACEXTABLE where Mission_Outcome like 'Success%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(100,)]

# %%
# %sql select count(Mission_Outcome) from SPACEXTABLE where Mission_Outcome like 'Failure%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1,)]

# %%
# %sql select count(Mission_Outcome) from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(101,)]

# %%
# %sql select count(*) from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(101,)]

# %%
# %sql select Mission_Outcome from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Failure (in flight)',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success (payload status unclear)',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
#  ('Success',),
# ...

# %% [markdown]
# Observe From Above:  The SPACEXTABLE Dataframe has 101 rows (flights).  All 101 rows contain a 'Mission_Outcome' of 'Success' or 'Failure.'  Of all 101 rows (flights), 100 of them have a 'Mission_Outcome' of 'Success,' and 1 of them has a 'Mission_Outcome' of 'Failure.'

# %% [markdown]
# ### Task 8
#
#
#
# ##### List all the booster_versions that have carried the maximum payload mass, using a subquery with a suitable aggregate function.

# %%
# PossAns:
# %sql select distinct Booster_Version from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 v1.0  B0003',),
#  ('F9 v1.0  B0004',),
#  ('F9 v1.0  B0005',),
#  ('F9 v1.0  B0006',),
#  ('F9 v1.0  B0007',),
#  ('F9 v1.1  B1003',),
#  ('F9 v1.1',),
#  ('F9 v1.1 B1011',),
#  ('F9 v1.1 B1010',),
#  ('F9 v1.1 B1012',),
#  ('F9 v1.1 B1013',),
#  ('F9 v1.1 B1014',),
#  ('F9 v1.1 B1015',),
#  ('F9 v1.1 B1016',),
#  ('F9 v1.1 B1018',),
#  ('F9 FT B1019',),
#  ('F9 v1.1 B1017',),
#  ('F9 FT B1020',),
#  ('F9 FT B1021.1',),
#  ('F9 FT B1022',),
#  ('F9 FT B1023.1',),
#  ('F9 FT B1024',),
#  ('F9 FT B1025.1',),
#  ('F9 FT B1026',),
#  ('F9 FT B1029.1',),
#  ('F9 FT B1031.1',),
#  ('F9 FT B1030',),
#  ('F9 FT  B1021.2',),
#  ('F9 FT B1032.1',),
#  ('F9 FT B1034',),
#  ('F9 FT B1035.1',),
#  ('F9 FT  B1029.2',),
#  ('F9 FT B1036.1',),
#  ('F9 FT B1037',),
#  ('F9 B4 B1039.1',),
#  ('F9 FT B1038.1',),
#  ('F9 B4 B1040.1',),
#  ('F9 B4 B1041.1',),
#  ('F9 FT  B1031.2',),
#  ('F9 B4 B1042.1',),
#  ('F9 FT  B1035.2',),
#  ('F9 FT  B1036.2',),
# ...

# %%
# %sql select count(distinct Booster_Version) from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(97,)]

# %%
# %sql select Booster_Version from SPACEXTABLE where PAYLOAD_MASS__KG_ = (select max(PAYLOAD_MASS__KG_) from SPACEXTABLE)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %%
# %sql select count(distinct Booster_Version) from SPACEXTABLE where PAYLOAD_MASS__KG_ = (select max(PAYLOAD_MASS__KG_) from SPACEXTABLE)
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(12,)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# %sql select substr(Date, 6, 2) , Landing_Outcome, Booster_Version, Launch_Site from SPACEXTABLE where Landing_Outcome like 'Failure%' and Landing_Outcome like '%drone%' and substr(Date,0,5) = '2015'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('04', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %%
# PossAns:
# %sql select Date, Landing_Outcome, Booster_Version, Launch_Site from SPACEXTABLE where Landing_Outcome like 'Failure%' and Landing_Outcome like '%drone%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-01-10', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('2015-04-14', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40'),
#  ('2016-01-17', 'Failure (drone ship)', 'F9 v1.1 B1017', 'VAFB SLC-4E'),
#  ('2016-03-04', 'Failure (drone ship)', 'F9 FT B1020', 'CCAFS LC-40'),
#  ('2016-06-15', 'Failure (drone ship)', 'F9 FT B1024', 'CCAFS LC-40')]

# %%
# %sql select Date, Landing_Outcome, Booster_Version, Launch_Site from SPACEXTABLE where Landing_Outcome like 'Success%' and Landing_Outcome like '%drone%'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2016-04-08', 'Success (drone ship)', 'F9 FT B1021.1', 'CCAFS LC-40'),
#  ('2016-05-06', 'Success (drone ship)', 'F9 FT B1022', 'CCAFS LC-40'),
#  ('2016-05-27', 'Success (drone ship)', 'F9 FT B1023.1', 'CCAFS LC-40'),
#  ('2016-08-14', 'Success (drone ship)', 'F9 FT B1026', 'CCAFS LC-40'),
#  ('2017-01-14', 'Success (drone ship)', 'F9 FT B1029.1', 'VAFB SLC-4E'),
#  ('2017-03-30', 'Success (drone ship)', 'F9 FT  B1021.2', 'KSC LC-39A'),
#  ('2017-06-23', 'Success (drone ship)', 'F9 FT  B1029.2', 'KSC LC-39A'),
#  ('2017-06-25', 'Success (drone ship)', 'F9 FT B1036.1', 'VAFB SLC-4E'),
#  ('2017-08-24', 'Success (drone ship)', 'F9 FT B1038.1', 'VAFB SLC-4E'),
#  ('2017-10-09', 'Success (drone ship)', 'F9 B4 B1041.1', 'VAFB SLC-4E'),
#  ('2017-10-11', 'Success (drone ship)', 'F9 FT  B1031.2', 'KSC LC-39A'),
#  ('2017-10-30', 'Success (drone ship)', 'F9 B4 B1042.1', 'KSC LC-39A'),
# ...

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %sql select Landing_Outcome, count(Landing_Outcome) from SPACEXTABLE where date >= '2010-06-04' and date <= '2017-03-20' group by Landing_Outcome order by count(Landing_Outcome) desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]

# %%
# PossAns:
# %sql select Date, Customer, PAYLOAD_MASS__KG_, Landing_Outcome from SPACEXTABLE where date >= '2010-06-04' and date <= '2017-03-20' order by date desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2017-03-16', 'EchoStar', 5600, 'No attempt'),
#  ('2017-02-19', 'NASA (CRS)', 2490, 'Success (ground pad)'),
#  ('2017-01-14', 'Iridium Communications', 9600, 'Success (drone ship)'),
#  ('2016-08-14', 'SKY Perfect JSAT Group', 4600, 'Success (drone ship)'),
#  ('2016-07-18', 'NASA (CRS)', 2257, 'Success (ground pad)'),
#  ('2016-06-15', 'ABS Eutelsat', 3600, 'Failure (drone ship)'),
#  ('2016-05-27', 'Thaicom', 3100, 'Success (drone ship)'),
#  ('2016-05-06', 'SKY Perfect JSAT Group', 4696, 'Success (drone ship)'),
#  ('2016-04-08', 'NASA (CRS)', 3136, 'Success (drone ship)'),
#  ('2016-03-04', 'SES', 5271, 'Failure (drone ship)'),
#  ('2016-01-17', 'NASA (LSP) NOAA CNES', 553, 'Failure (drone ship)'),
#  ('2015-12-22', 'Orbcomm', 2034, 'Success (ground pad)'),
#  ('2015-06-28', 'NASA (CRS)', 1952, 'Precluded (drone ship)'),
#  ('2015-04-27', 'Turkmenistan National Space Agency', 4707, 'No attempt'),
# ...

# %%
# PossAns:
# %sql select Date, Customer, Booster_Version, PAYLOAD_MASS__KG_, Landing_Outcome from SPACEXTABLE where date >= '2010-06-04' and date <= '2017-03-20' order by date desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2017-03-16', 'EchoStar', 'F9 FT B1030', 5600, 'No attempt'),
#  ('2017-02-19', 'NASA (CRS)', 'F9 FT B1031.1', 2490, 'Success (ground pad)'),
#  ('2017-01-14', 'Iridium Communications', 'F9 FT B1029.1', 9600, 'Success (drone ship)'),
#  ('2016-08-14', 'SKY Perfect JSAT Group', 'F9 FT B1026', 4600, 'Success (drone ship)'),
#  ('2016-07-18', 'NASA (CRS)', 'F9 FT B1025.1', 2257, 'Success (ground pad)'),
#  ('2016-06-15', 'ABS Eutelsat', 'F9 FT B1024', 3600, 'Failure (drone ship)'),
#  ('2016-05-27', 'Thaicom', 'F9 FT B1023.1', 3100, 'Success (drone ship)'),
#  ('2016-05-06', 'SKY Perfect JSAT Group', 'F9 FT B1022', 4696, 'Success (drone ship)'),
#  ('2016-04-08', 'NASA (CRS)', 'F9 FT B1021.1', 3136, 'Success (drone ship)'),
#  ('2016-03-04', 'SES', 'F9 FT B1020', 5271, 'Failure (drone ship)'),
#  ('2016-01-17', 'NASA (LSP) NOAA CNES', 'F9 v1.1 B1017', 553, 'Failure (drone ship)'),
# ...

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# <!--
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2024-07-10 | 1.1 |Anita Verma | Changed Version|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |
# -->

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
